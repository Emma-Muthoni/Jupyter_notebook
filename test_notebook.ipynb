# %%
import pandas as pd

# 1. Create a structured dataset using a Python dictionary
student_data = {
    "Student Name": ["Emma Muthoni", "John Omwamba", "Aminata Keitany", "David Ochieng"],
    "Python Score": [92, 85, 78, 95],
    "Cybersecurity Score": [88, 90, 82, 89],
    "Graduation Status": ["On Track", "On Track", "Review Needed", "On Track"]
}

# 2. Convert the dictionary into a formal Pandas DataFrame
df = pd.DataFrame(student_data)

# 3. Calculate the average Python score automatically
average_python = df["Python Score"].mean()
print(f"The class average score for Python is: {average_python}%\n")

# 4. Simply type the variable name to render a beautiful visual table
df
# Out:
# The class average score for Python is: 87.5%
#       Student Name  Python Score  Cybersecurity Score Graduation Status
# 0     Emma Muthoni            92                   88          On Track
# 1     John Omwamba            85                   90          On Track
# 2  Aminata Keitany            78                   82     Review Needed
# 3    David Ochieng            95                   89          On Track
